# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %%
data = pd.read_csv("dataset/metadata.csv", nrows=200_000, low_memory=False)
data.head(10)
# Out:
#    cord_uid                                       sha source_x  \
# 0  ug7v899j  d1aafb70c066a2068b02786f8929fd9c900897fb      PMC
# 1  02tnwd4m  6b0567729c2143a66d737eb0a2f63f2dce2e5a7d      PMC
# 2  ejv2xln0  06ced00a5fc04215949aa72528f2eeaae1d58927      PMC
# 3  2b73a28n  348055649b6b8cf2b9a376498df9bf41f7123605      PMC
# 4  9785vg6d  5f48792a5fa08bed9f56016f4981ae2ca6031b32      PMC
# 5  zjufx4fo  b2897e1277f56641193a6db73825f707eed3e4c9      PMC
# 6  5yhe786e  3bb07ea10432f7738413dff9816809cc90f03f99      PMC
# 7  8zchiykl  5806726a24dc91de3954001effbdffd7a82d54e2      PMC
# 8  8qnrcgnk  faaf1022ccfe93b032c5608097a53543ba24aedb      PMC
# 9  jg13scgo  5b44feca5d6ffaaeb66501fa84cc6dd44d06660a      PMC
#
#                                                title  \
# 0  Clinical features of culture-proven Mycoplasma...
# 1  Nitric oxide: a pro-inflammatory mediator in l...
# 2    Surfactant protein-D and pulmonary host defense
# 3               Role of endothelin-1 in lung disease
# ...

# %%
data.shape
# Out:
# (500000, 19)

# %%
data.head()
# Out:
#    cord_uid                                       sha source_x  \
# 0  ug7v899j  d1aafb70c066a2068b02786f8929fd9c900897fb      PMC
# 1  02tnwd4m  6b0567729c2143a66d737eb0a2f63f2dce2e5a7d      PMC
# 2  ejv2xln0  06ced00a5fc04215949aa72528f2eeaae1d58927      PMC
# 3  2b73a28n  348055649b6b8cf2b9a376498df9bf41f7123605      PMC
# 4  9785vg6d  5f48792a5fa08bed9f56016f4981ae2ca6031b32      PMC
#
#                                                title                    doi  \
# 0  Clinical features of culture-proven Mycoplasma...  10.1186/1471-2334-1-6
# 1  Nitric oxide: a pro-inflammatory mediator in l...           10.1186/rr14
# 2    Surfactant protein-D and pulmonary host defense           10.1186/rr19
# 3               Role of endothelin-1 in lung disease           10.1186/rr44
# 4  Gene expression in epithelial cells in respons...           10.1186/rr61
#
#       pmcid pubmed_id license  \
# 0  PMC35282  11472636   no-cc
# 1  PMC59543  11667967   no-cc
# 2  PMC59549  11667972   no-cc
# ...

# %%
data.columns
# Out:
# Index(['cord_uid', 'sha', 'source_x', 'title', 'doi', 'pmcid', 'pubmed_id',
#        'license', 'abstract', 'publish_time', 'authors', 'journal', 'mag_id',
#        'who_covidence_id', 'arxiv_id', 'pdf_json_files', 'pmc_json_files',
#        'url', 's2_id'],
#       dtype='object')

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 500000 entries, 0 to 499999
# Data columns (total 19 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   cord_uid          500000 non-null  object
#  1   sha               73212 non-null   object
#  2   source_x          500000 non-null  object
#  3   title             499576 non-null  object
#  4   doi               282393 non-null  object
#  5   pmcid             80192 non-null   object
#  6   pubmed_id         164884 non-null  object
#  7   license           500000 non-null  object
#  8   abstract          380454 non-null  object
#  9   publish_time      498541 non-null  object
#  10  authors           483703 non-null  object
#  11  journal           448280 non-null  object
#  12  mag_id            0 non-null       float64
#  13  who_covidence_id  272042 non-null  object
#  14  arxiv_id          7513 non-null    object
#  15  pdf_json_files    73212 non-null   object
# ...

# %%
data.isnull().sum()
# Out:
# cord_uid                 0
# sha                 426788
# source_x                 0
# title                  424
# doi                 217607
# pmcid               419808
# pubmed_id           335116
# license                  0
# abstract            119546
# publish_time          1459
# authors              16297
# journal              51720
# mag_id              500000
# who_covidence_id    227958
# arxiv_id            492487
# pdf_json_files      426788
# pmc_json_files      444185
# url                 193666
# s2_id                80192
# dtype: int64

# %%
data.describe()
# Out:
#        mag_id         s2_id
# count     0.0  4.198080e+05
# mean      NaN  2.114174e+08
# std       NaN  6.117972e+07
# min       NaN  1.695000e+03
# 25%       NaN  2.207159e+08
# 50%       NaN  2.316820e+08
# 75%       NaN  2.360908e+08
# max       NaN  2.491936e+08

# %%
data.isnull().sum()
# Out:
# cord_uid                 0
# sha                 426788
# source_x                 0
# title                  424
# doi                 217607
# pmcid               419808
# pubmed_id           335116
# license                  0
# abstract            119546
# publish_time          1459
# authors              16297
# journal              51720
# mag_id              500000
# who_covidence_id    227958
# arxiv_id            492487
# pdf_json_files      426788
# pmc_json_files      444185
# url                 193666
# s2_id                80192
# dtype: int64

# %%
data = data.drop(
    columns=[
        "cord_uid",
        "sha",
        "doi",
        "pmcid",
        "pubmed_id",
        "abstract",
        "mag_id",
        "who_covidence_id",
        "arxiv_id",
        "pdf_json_files",
        "pmc_json_files",
        "url",
        "s2_id"
    ]
)

# %%
data.sample(5)
# Out:
#        source_x                                              title license  \
# 364275      WHO  A College of Nursing's Upward Spiral During a ...     unk
# 279913      WHO  Data-Driven Optimal Design of a CHP Plant for ...     unk
# 254051      WHO  Beyond the Disease: Contextualized Implication...   cc-by
# 79621   Medline  Endoscopic mucosal resection of large colonic ...     unk
# 1886        PMC  Nogo-B protects mice against lipopolysaccharid...   cc-by
#
#        publish_time                                            authors  \
# 364275         2020       Mariani, Bette; Havens, Donna S; Metz, Sarah
# 279913         2022  Bartolucci, Lorenzo Cordiner Stefano De Maina ...
# 254051         2020  Govender, Kaymarlin Cowden Richard Nyamruze Pa...
# 79621    2020-12-14  Lisotti, Andrea; Marocchi, Gianmarco; Calì, An...
# 1886     2015-07-15  Xu, Wujian; Zhu, Ying; Ning, Yunye; Dong, Yuch...
#
#                                                   journal
# ...

# %%
data = data.drop("source_x", axis=1)
data.sample(5)
# Out:
#                                                     title license  \
# 271112  Prediction of Potential 3CLpro-Targeting Anti-...   cc-by
# 259130  Impact of the Covid-19 Pandemic on Activities ...     unk
# 406356  Lifestyle Changes Among Medical Students Durin...     unk
# 461020  RESEARCHFactors Associated with Nursing Homes'...     unk
# 352685  Proton Pump Inhibitor Use Is Not Strongly Asso...     unk
#
#        publish_time                                            authors  \
# 271112         2020                 Sun, Ning Wong Wing-Leung Guo Jiao
# 259130         2021             Hendrik, H.; Hendri, R.; Yolandika, C.
# 406356         2021  Perez-Dominguez, Francisco; Polanco-Ilabaca, F...
# 461020         2020               Li, Yumeng; Fang, Fang; He, Mengying
# 352685         2021  Israelsen, Simone Bastrup; Ernst, Martin Thoms...
#
#                                                   journal
# 271112                                                NaN
# ...

# %%
data.columns
# Out:
# Index(['title', 'license', 'publish_time', 'authors', 'journal'], dtype='object')
